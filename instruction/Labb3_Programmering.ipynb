# %% [markdown]
# Lab 3
# In this lab, we will investigate a linear classification. This lab should be submitted as a `.py` file (your code), a `README.md` file describing what your program does and how to use it, as well as a `labelled_data.csv` file (the answer to the assignment). For a distinction grade (VG), a `report.ipynb` file should also be included in the repository.
#
# Tasks:
#
# a) Start by reading the file `unlabelled_data.csv` and plot its contents in a scatterplot. You do not need to submit this part—it is for your own understanding to proceed to the next step. You may use either a Jupyter notebook or a Python script, whichever you find easiest.
#
# b) Draw a straight line through the figure that separates the points as evenly as possible. Determine the equation of this line in the form (y = kx + m).
# *Hint:* Think about what the values must be when (x = 0) or (y = 0).
#
# c) Implement a function that calculates whether a point lies above/to the right of or below/to the left of the line. For now, write code that you will submit. Write this function in a `.py` file.
# Hint: If the y-value of a point is greater than the value of the line for the corresponding x, what does that mean?
#
# d) Create a program that uses the function from the previous task to classify all points in the `unlabelled_data.csv` file.
#
# e) Write to a file `labelled_data.csv`, adding a column with `0` if the point is to the left of the line and `1` otherwise.
#
# f) Display a window with a graph showing the points, their class, and your line.
#
# Distinction (VG) tasks:
#
# For VG, you should also submit a very short report as a Jupyter notebook. The report should include the following:
#
# i) Show the data in a graph along with the following lines in addition to your own:
#
#  (f(x) = -0.489x)
#  (g(x) = -2x + 0.16)
# *(h(x) = 800x - 120)
#
# ii) Also use these new functions to classify the data. Are there any differences?
#
# iii) Discuss whether there is any reason to prefer one line over another. How many such lines can we find?
#
# Write in continuous text as Markdown cells. Make sure the Python code cells are concise and connected to the surrounding text. The report should be reasoning-focused but does not require references. Show your thought process using text, code, and graphs. Reuse code wherever possible.
